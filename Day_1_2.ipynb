# %% [markdown]
# <a href="https://colab.research.google.com/github/sher-ali-khan/Coding_Challenge-8/blob/master/Day_1_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("hello world!")
# Out:
# hello world!

# %%
#Arthmetic operators
# + - Addition
# - - Subtraction
# * - Multiplication
# / - Division
# // - Integer Division
# ** - exponentiation
# %  - Remainder
a, b =5,6
print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a%b)
print(a**b)
print(a//b)
# Out:
# 11
# -1
# 30
# 0.8333333333333334
# 5
# 15625
# 0
